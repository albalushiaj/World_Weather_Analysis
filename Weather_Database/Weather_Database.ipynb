# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import the requests library
import requests

# import the API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 587

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                       "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | bambous virieux
# Processing Record 5 of Set 1 | tura
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | kasongo-lunda
# Processing Record 9 of Set 1 | port lincoln
# Processing Record 10 of Set 1 | celestun
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | belaya gora
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | svetlaya
# Processing Record 19 of Set 1 | paamiut
# Processing Record 20 of Set 1 | mayumba
# Processing Record 21 of Set 1 | san cristobal
# Processing Record 22 of Set 1 | oktyabrskoye
# Processing Record 23 of Set 1 | bengkulu
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | adrar
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | sobolevo
# Processing Record 32 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 1 | oksfjord
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | kutum
# Processing Record 36 of Set 1 | aromashevo
# Processing Record 37 of Set 1 | husavik
# Processing Record 38 of Set 1 | airai
# Processing Record 39 of Set 1 | lasa
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | wukari
# Processing Record 42 of Set 1 | comodoro rivadavia
# Processing Record 43 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | amritsar
# Processing Record 50 of Set 1 | mayor pablo lagerenza
# Processing Record 1 of Set 2 | kpandu
# Processing Record 2 of Set 2 | richards bay
# Processing Record 3 of Set 2 | manica
# Processing Record 4 of Set 2 | manoel urbano
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | kununurra
# Processing Record 7 of Set 2 | magalia
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | batagay-alyta
# Processing Record 10 of Set 2 | yatou
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | alekseyevsk
# Processing Record 15 of Set 2 | ligayan
# Processing Record 16 of Set 2 | saint anthony
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | qaqortoq
# Processing Record 19 of Set 2 | amapa
# Processing Record 20 of Set 2 | vila franca do campo
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | faanui
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | bandarbeyla
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | leningradskiy
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | cabedelo
# Processing Record 30 of Set 2 | walvis bay
# Processing Record 31 of Set 2 | berlevag
# Processing Record 32 of Set 2 | anloga
# Processing Record 33 of Set 2 | mataura
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | havre-saint-pierre
# Processing Record 38 of Set 2 | ust-ishim
# Processing Record 39 of Set 2 | necochea
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | moose factory
# Processing Record 42 of Set 2 | bladel
# Processing Record 43 of Set 2 | sao filipe
# Processing Record 44 of Set 2 | safidon
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | concarneau
# Processing Record 47 of Set 2 | bentiu
# Processing Record 48 of Set 2 | atagay
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | severo-kurilsk
# Processing Record 1 of Set 3 | mackenzie
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | itacare
# Processing Record 5 of Set 3 | aranos
# Processing Record 6 of Set 3 | urcos
# Processing Record 7 of Set 3 | castro
# Processing Record 8 of Set 3 | flin flon
# Processing Record 9 of Set 3 | raudeberg
# Processing Record 10 of Set 3 | novikovo
# Processing Record 11 of Set 3 | alexandria
# Processing Record 12 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 3 | orlik
# Processing Record 14 of Set 3 | lazi
# Processing Record 15 of Set 3 | sinnamary
# Processing Record 16 of Set 3 | haimen
# Processing Record 17 of Set 3 | maposeni
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | grindavik
# Processing Record 20 of Set 3 | maumere
# Processing Record 21 of Set 3 | broome
# Processing Record 22 of Set 3 | atuona
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 3 | dhidhdhoo
# Processing Record 26 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 3 | mount isa
# Processing Record 28 of Set 3 | turukhansk
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | lazaro cardenas
# Processing Record 31 of Set 3 | west linton
# Processing Record 32 of Set 3 | wuda
# Processing Record 33 of Set 3 | nyuksenitsa
# Processing Record 34 of Set 3 | ati
# Processing Record 35 of Set 3 | sibu
# Processing Record 36 of Set 3 | coahuayana
# Processing Record 37 of Set 3 | aquiraz
# Processing Record 38 of Set 3 | xiongzhou
# Processing Record 39 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 3 | americo brasiliense
# Processing Record 41 of Set 3 | sept-iles
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | san quintin
# Processing Record 45 of Set 3 | qaanaaq
# Processing Record 46 of Set 3 | lavrentiya
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | deer lake
# Processing Record 49 of Set 3 | ulundi
# Processing Record 50 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 4 | yakeshi
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | acaxochitlan
# Processing Record 4 of Set 4 | hilo
# Processing Record 5 of Set 4 | nouadhibou
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | cairns
# Processing Record 8 of Set 4 | warkworth
# Processing Record 9 of Set 4 | avera
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | yuci
# Processing Record 12 of Set 4 | inongo
# Processing Record 13 of Set 4 | soyo
# Processing Record 14 of Set 4 | baruun-urt
# Processing Record 15 of Set 4 | fortuna
# Processing Record 16 of Set 4 | bathsheba
# Processing Record 17 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 18 of Set 4 | lebu
# Processing Record 19 of Set 4 | touros
# Processing Record 20 of Set 4 | fairbanks
# Processing Record 21 of Set 4 | djibo
# Processing Record 22 of Set 4 | eyl
# Processing Record 23 of Set 4 | dingle
# Processing Record 24 of Set 4 | wajir
# Processing Record 25 of Set 4 | vilhena
# Processing Record 26 of Set 4 | calabozo
# Processing Record 27 of Set 4 | lugovoy
# Processing Record 28 of Set 4 | ellington
# Processing Record 29 of Set 4 | emerald
# Processing Record 30 of Set 4 | thinadhoo
# Processing Record 31 of Set 4 | porto novo
# Processing Record 32 of Set 4 | dale
# Processing Record 33 of Set 4 | byron bay
# Processing Record 34 of Set 4 | shwebo
# Processing Record 35 of Set 4 | trincomalee
# Processing Record 36 of Set 4 | sambava
# Processing Record 37 of Set 4 | camabatela
# Processing Record 38 of Set 4 | hami
# Processing Record 39 of Set 4 | owando
# Processing Record 40 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 4 | aklavik
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | nalut
# Processing Record 44 of Set 4 | salalah
# Processing Record 45 of Set 4 | grand gaube
# Processing Record 46 of Set 4 | pangnirtung
# Processing Record 47 of Set 4 | tevaitoa
# Processing Record 48 of Set 4 | warrnambool
# Processing Record 49 of Set 4 | pipri
# Processing Record 50 of Set 4 | sola
# Processing Record 1 of Set 5 | tiksi
# Processing Record 2 of Set 5 | umm kaddadah
# Processing Record 3 of Set 5 | jacqueville
# Processing Record 4 of Set 5 | singkawang
# Processing Record 5 of Set 5 | belmonte
# Processing Record 6 of Set 5 | iracoubo
# Processing Record 7 of Set 5 | santa isabel do rio negro
# Processing Record 8 of Set 5 | santarem
# Processing Record 9 of Set 5 | marovoay
# Processing Record 10 of Set 5 | half moon bay
# Processing Record 11 of Set 5 | tual
# Processing Record 12 of Set 5 | dabhol
# Processing Record 13 of Set 5 | ribeira grande
# Processing Record 14 of Set 5 | isla vista
# Processing Record 15 of Set 5 | benghazi
# Processing Record 16 of Set 5 | pevek
# Processing Record 17 of Set 5 | logrono
# Processing Record 18 of Set 5 | hosakote
# Processing Record 19 of Set 5 | alta floresta
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | baykit
# Processing Record 22 of Set 5 | mitsamiouli
# Processing Record 23 of Set 5 | bonavista
# Processing Record 24 of Set 5 | lagoa
# Processing Record 25 of Set 5 | massakory
# Processing Record 26 of Set 5 | zeya
# Processing Record 27 of Set 5 | hasaki
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | lianran
# Processing Record 30 of Set 5 | mankono
# Processing Record 31 of Set 5 | turtkul
# City not found. Skipping...
# Processing Record 32 of Set 5 | el reno
# Processing Record 33 of Set 5 | henties bay
# Processing Record 34 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 5 | katsuura
# Processing Record 36 of Set 5 | ilinskoye-khovanskoye
# Processing Record 37 of Set 5 | roma
# Processing Record 38 of Set 5 | buon me thuot
# City not found. Skipping...
# Processing Record 39 of Set 5 | veinticinco de mayo
# Processing Record 40 of Set 5 | nanortalik
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | banda aceh
# Processing Record 43 of Set 5 | saldanha
# Processing Record 44 of Set 5 | kuala terengganu
# Processing Record 45 of Set 5 | bereznik
# Processing Record 46 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 5 | viedma
# Processing Record 48 of Set 5 | karratha
# Processing Record 49 of Set 5 | maltahohe
# Processing Record 50 of Set 5 | san jose
# Processing Record 1 of Set 6 | seymchan
# Processing Record 2 of Set 6 | saint-augustin
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | pampierstad
# Processing Record 5 of Set 6 | norman wells
# Processing Record 6 of Set 6 | mercedes
# Processing Record 7 of Set 6 | hualmay
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | toamasina
# Processing Record 10 of Set 6 | vikhorevka
# Processing Record 11 of Set 6 | paris
# Processing Record 12 of Set 6 | sur
# Processing Record 13 of Set 6 | taltal
# Processing Record 14 of Set 6 | ulladulla
# Processing Record 15 of Set 6 | kahama
# Processing Record 16 of Set 6 | mount gambier
# Processing Record 17 of Set 6 | sigli
# Processing Record 18 of Set 6 | havoysund
# Processing Record 19 of Set 6 | kanniyakumari
# Processing Record 20 of Set 6 | sarakhs
# Processing Record 21 of Set 6 | magaria
# Processing Record 22 of Set 6 | soto la marina
# Processing Record 23 of Set 6 | kwekwe
# Processing Record 24 of Set 6 | margate
# Processing Record 25 of Set 6 | quatre cocos
# Processing Record 26 of Set 6 | portland
# Processing Record 27 of Set 6 | chimbote
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | fagernes
# Processing Record 30 of Set 6 | guerrero negro
# Processing Record 31 of Set 6 | arraial do cabo
# Processing Record 32 of Set 6 | yar-sale
# Processing Record 33 of Set 6 | altamira
# Processing Record 34 of Set 6 | tilichiki
# Processing Record 35 of Set 6 | barrow
# Processing Record 36 of Set 6 | komsomolskiy
# Processing Record 37 of Set 6 | ancud
# Processing Record 38 of Set 6 | tecoanapa
# Processing Record 39 of Set 6 | olavarria
# Processing Record 40 of Set 6 | wolmaranstad
# City not found. Skipping...
# Processing Record 41 of Set 6 | tottori
# Processing Record 42 of Set 6 | coquimbo
# Processing Record 43 of Set 6 | erenhot
# Processing Record 44 of Set 6 | kavaratti
# Processing Record 45 of Set 6 | ponta do sol
# Processing Record 46 of Set 6 | sao felix do xingu
# Processing Record 47 of Set 6 | ishigaki
# Processing Record 48 of Set 6 | okhotsk
# Processing Record 49 of Set 6 | ierapetra
# Processing Record 50 of Set 6 | palora
# Processing Record 1 of Set 7 | daru
# Processing Record 2 of Set 7 | toppenish
# Processing Record 3 of Set 7 | iquique
# Processing Record 4 of Set 7 | sahuaripa
# Processing Record 5 of Set 7 | verkhnevilyuysk
# Processing Record 6 of Set 7 | pisco
# Processing Record 7 of Set 7 | pandan
# Processing Record 8 of Set 7 | tecpan
# Processing Record 9 of Set 7 | yerbogachen
# Processing Record 10 of Set 7 | karonga
# Processing Record 11 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 7 | grand-santi
# Processing Record 13 of Set 7 | geraldton
# Processing Record 14 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 7 | san blas
# Processing Record 16 of Set 7 | guangyuan
# Processing Record 17 of Set 7 | kimbe
# Processing Record 18 of Set 7 | muros
# Processing Record 19 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 7 | longyearbyen
# Processing Record 21 of Set 7 | inhambane
# Processing Record 22 of Set 7 | amambai
# Processing Record 23 of Set 7 | houma
# Processing Record 24 of Set 7 | cockburn town
# Processing Record 25 of Set 7 | arman
# Processing Record 26 of Set 7 | kiama
# Processing Record 27 of Set 7 | ahipara
# Processing Record 28 of Set 7 | dalen
# Processing Record 29 of Set 7 | kamenka
# Processing Record 30 of Set 7 | liverpool
# Processing Record 31 of Set 7 | loandjili
# Processing Record 32 of Set 7 | vao
# Processing Record 33 of Set 7 | goure
# Processing Record 34 of Set 7 | kerrville
# Processing Record 35 of Set 7 | xichang
# Processing Record 36 of Set 7 | shubarkuduk
# Processing Record 37 of Set 7 | abu dhabi
# Processing Record 38 of Set 7 | kavieng
# Processing Record 39 of Set 7 | lompoc
# Processing Record 40 of Set 7 | kaeo
# Processing Record 41 of Set 7 | mangrol
# Processing Record 42 of Set 7 | vardo
# Processing Record 43 of Set 7 | perehonivka
# Processing Record 44 of Set 7 | dahanu
# Processing Record 45 of Set 7 | northam
# Processing Record 46 of Set 7 | kaduy
# Processing Record 47 of Set 7 | provideniya
# Processing Record 48 of Set 7 | khorinsk
# Processing Record 49 of Set 7 | brae
# Processing Record 50 of Set 7 | wasilla
# Processing Record 1 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 8 | egvekinot
# Processing Record 3 of Set 8 | nara
# Processing Record 4 of Set 8 | petauke
# Processing Record 5 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 8 | alofi
# Processing Record 7 of Set 8 | atambua
# Processing Record 8 of Set 8 | pidhorodne
# Processing Record 9 of Set 8 | cordoba
# Processing Record 10 of Set 8 | flinders
# Processing Record 11 of Set 8 | loa janan
# Processing Record 12 of Set 8 | imbituba
# Processing Record 13 of Set 8 | klaksvik
# Processing Record 14 of Set 8 | beringovskiy
# Processing Record 15 of Set 8 | marathon
# Processing Record 16 of Set 8 | shihezi
# Processing Record 17 of Set 8 | nenjiang
# Processing Record 18 of Set 8 | sayyan
# Processing Record 19 of Set 8 | olafsvik
# Processing Record 20 of Set 8 | lucapa
# Processing Record 21 of Set 8 | sundsvall
# Processing Record 22 of Set 8 | praia da vitoria
# Processing Record 23 of Set 8 | burica
# City not found. Skipping...
# Processing Record 24 of Set 8 | kuldur
# Processing Record 25 of Set 8 | hamilton
# Processing Record 26 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 8 | bako
# Processing Record 28 of Set 8 | batemans bay
# Processing Record 29 of Set 8 | sonoita
# Processing Record 30 of Set 8 | balakhta
# Processing Record 31 of Set 8 | oistins
# Processing Record 32 of Set 8 | tiruvottiyur
# City not found. Skipping...
# Processing Record 33 of Set 8 | mareeba
# Processing Record 34 of Set 8 | kahului
# Processing Record 35 of Set 8 | yeppoon
# Processing Record 36 of Set 8 | kenai
# Processing Record 37 of Set 8 | eureka
# Processing Record 38 of Set 8 | qiongshan
# Processing Record 39 of Set 8 | abapo
# Processing Record 40 of Set 8 | longforgan
# Processing Record 41 of Set 8 | puerto suarez
# Processing Record 42 of Set 8 | bang saphan
# Processing Record 43 of Set 8 | dzemul
# Processing Record 44 of Set 8 | bahia blanca
# Processing Record 45 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 8 | hirara
# Processing Record 47 of Set 8 | zaidpur
# Processing Record 48 of Set 8 | mayo
# Processing Record 49 of Set 8 | faya
# Processing Record 50 of Set 8 | sioux city
# Processing Record 1 of Set 9 | fernandez
# Processing Record 2 of Set 9 | asau
# Processing Record 3 of Set 9 | la ronge
# Processing Record 4 of Set 9 | astara
# Processing Record 5 of Set 9 | wageningen
# Processing Record 6 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 7 of Set 9 | namibe
# Processing Record 8 of Set 9 | sim
# Processing Record 9 of Set 9 | jinchang
# Processing Record 10 of Set 9 | kulhudhuffushi
# Processing Record 11 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 9 | leua
# Processing Record 14 of Set 9 | kruisfontein
# Processing Record 15 of Set 9 | cap malheureux
# Processing Record 16 of Set 9 | chapais
# Processing Record 17 of Set 9 | zambrano
# Processing Record 18 of Set 9 | ghanzi
# Processing Record 19 of Set 9 | fethiye
# Processing Record 20 of Set 9 | san policarpo
# Processing Record 21 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 9 | chaozhou
# Processing Record 23 of Set 9 | salme
# Processing Record 24 of Set 9 | princeton
# Processing Record 25 of Set 9 | kropotkin
# Processing Record 26 of Set 9 | kondinskoye
# Processing Record 27 of Set 9 | markova
# Processing Record 28 of Set 9 | kuching
# Processing Record 29 of Set 9 | port blair
# Processing Record 30 of Set 9 | ous
# Processing Record 31 of Set 9 | taraz
# Processing Record 32 of Set 9 | sol-iletsk
# Processing Record 33 of Set 9 | kalabo
# Processing Record 34 of Set 9 | cayenne
# Processing Record 35 of Set 9 | auki
# Processing Record 36 of Set 9 | deputatskiy
# Processing Record 37 of Set 9 | trairi
# Processing Record 38 of Set 9 | ponta delgada
# Processing Record 39 of Set 9 | yialos
# City not found. Skipping...
# Processing Record 40 of Set 9 | tsabong
# Processing Record 41 of Set 9 | paramonga
# Processing Record 42 of Set 9 | zacatecas
# Processing Record 43 of Set 9 | abu samrah
# Processing Record 44 of Set 9 | christchurch
# Processing Record 45 of Set 9 | pimentel
# Processing Record 46 of Set 9 | constitucion
# Processing Record 47 of Set 9 | dunedin
# Processing Record 48 of Set 9 | pascagoula
# Processing Record 49 of Set 9 | pandelys
# City not found. Skipping...
# Processing Record 50 of Set 9 | bowen
# Processing Record 1 of Set 10 | matola
# Processing Record 2 of Set 10 | sioux lookout
# Processing Record 3 of Set 10 | ajdabiya
# Processing Record 4 of Set 10 | kirakira
# Processing Record 5 of Set 10 | staraya poltavka
# Processing Record 6 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 10 | tanggu
# Processing Record 8 of Set 10 | yaviza
# Processing Record 9 of Set 10 | ostrovnoy
# Processing Record 10 of Set 10 | victoria
# Processing Record 11 of Set 10 | kudahuvadhoo
# Processing Record 12 of Set 10 | pidhaytsi
# Processing Record 13 of Set 10 | xam nua
# Processing Record 14 of Set 10 | tiznit
# Processing Record 15 of Set 10 | moron
# Processing Record 16 of Set 10 | presque isle
# Processing Record 17 of Set 10 | astoria
# Processing Record 18 of Set 10 | agadez
# Processing Record 19 of Set 10 | douglasville
# Processing Record 20 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 10 | bagdarin
# Processing Record 22 of Set 10 | cotusca
# Processing Record 23 of Set 10 | najran
# Processing Record 24 of Set 10 | kaitangata
# Processing Record 25 of Set 10 | maloy
# Processing Record 26 of Set 10 | yumen
# Processing Record 27 of Set 10 | novo aripuana
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | winnemucca
# Processing Record 30 of Set 10 | khandyga
# Processing Record 31 of Set 10 | mandurah
# Processing Record 32 of Set 10 | makakilo city
# Processing Record 33 of Set 10 | san andres
# Processing Record 34 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 35 of Set 10 | valenca
# Processing Record 36 of Set 10 | oussouye
# Processing Record 37 of Set 10 | pitimbu
# Processing Record 38 of Set 10 | stokmarknes
# Processing Record 39 of Set 10 | jobat
# Processing Record 40 of Set 10 | korla
# Processing Record 41 of Set 10 | cuautlancingo
# Processing Record 42 of Set 10 | topolobampo
# Processing Record 43 of Set 10 | obligado
# Processing Record 44 of Set 10 | krasnoselkup
# Processing Record 45 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 46 of Set 10 | lata
# Processing Record 47 of Set 10 | turkistan
# Processing Record 48 of Set 10 | narrabri
# Processing Record 49 of Set 10 | nordhausen
# Processing Record 50 of Set 10 | east london
# Processing Record 1 of Set 11 | strezhevoy
# Processing Record 2 of Set 11 | meiganga
# Processing Record 3 of Set 11 | revda
# Processing Record 4 of Set 11 | tamandare
# Processing Record 5 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 11 | bermeo
# Processing Record 7 of Set 11 | soloneshnoye
# Processing Record 8 of Set 11 | dingli
# Processing Record 9 of Set 11 | rio gallegos
# Processing Record 10 of Set 11 | galle
# Processing Record 11 of Set 11 | taicheng
# Processing Record 12 of Set 11 | beyla
# Processing Record 13 of Set 11 | fujin
# Processing Record 14 of Set 11 | palu
# Processing Record 15 of Set 11 | escarcega
# Processing Record 16 of Set 11 | adre
# Processing Record 17 of Set 11 | iqaluit
# Processing Record 18 of Set 11 | laguna
# Processing Record 19 of Set 11 | kouango
# Processing Record 20 of Set 11 | maningrida
# Processing Record 21 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 11 | la ligua
# Processing Record 23 of Set 11 | tuy hoa
# Processing Record 24 of Set 11 | nishihara
# Processing Record 25 of Set 11 | ta khmau
# Processing Record 26 of Set 11 | varhaug
# Processing Record 27 of Set 11 | morro bay
# Processing Record 28 of Set 11 | haines junction
# Processing Record 29 of Set 11 | xunchang
# Processing Record 30 of Set 11 | lantawan
# Processing Record 31 of Set 11 | severodvinsk
# Processing Record 32 of Set 11 | usinsk
# Processing Record 33 of Set 11 | hornepayne
# Processing Record 34 of Set 11 | urubicha
# Processing Record 35 of Set 11 | lewiston
# Processing Record 36 of Set 11 | namatanai
# Processing Record 37 of Set 11 | mabaruma
# Processing Record 38 of Set 11 | wanaka
# Processing Record 39 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 40 of Set 11 | oxapampa
# Processing Record 41 of Set 11 | stefanesti
# Processing Record 42 of Set 11 | bubaque
# Processing Record 43 of Set 11 | rocha
# Processing Record 44 of Set 11 | sanchursk
# Processing Record 45 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 11 | green river
# Processing Record 47 of Set 11 | drayton valley
# Processing Record 48 of Set 11 | derazhnya
# Processing Record 49 of Set 11 | itarema
# Processing Record 50 of Set 11 | port macquarie
# Processing Record 1 of Set 12 | san lawrenz
# Processing Record 2 of Set 12 | omboue
# Processing Record 3 of Set 12 | changli
# Processing Record 4 of Set 12 | george town
# Processing Record 5 of Set 12 | shingu
# Processing Record 6 of Set 12 | sosnogorsk
# Processing Record 7 of Set 12 | holiday
# Processing Record 8 of Set 12 | yubileynyy
# Processing Record 9 of Set 12 | merauke
# Processing Record 10 of Set 12 | luanda
# Processing Record 11 of Set 12 | mangan
# Processing Record 12 of Set 12 | farah
# Processing Record 13 of Set 12 | isangel
# Processing Record 14 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 15 of Set 12 | troitsk
# Processing Record 16 of Set 12 | harper
# Processing Record 17 of Set 12 | shieli
# Processing Record 18 of Set 12 | maniitsoq
# Processing Record 19 of Set 12 | yinchuan
# Processing Record 20 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 12 | udachnyy
# Processing Record 22 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 12 | opuwo
# Processing Record 24 of Set 12 | gazli
# Processing Record 25 of Set 12 | estelle
# Processing Record 26 of Set 12 | lorengau
# Processing Record 27 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 12 | georgetown
# Processing Record 29 of Set 12 | poum
# Processing Record 30 of Set 12 | vicuna
# Processing Record 31 of Set 12 | kampene
# Processing Record 32 of Set 12 | iquitos
# Processing Record 33 of Set 12 | yenotayevka
# Processing Record 34 of Set 12 | charyshskoye
# Processing Record 35 of Set 12 | lethem
# Processing Record 36 of Set 12 | newport
# Processing Record 37 of Set 12 | la paz centro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 539

# %%
# Add city data to new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Elizabeth -33.9180   25.5701     60.31        97          75
# 1          Rikitea -23.1203 -134.9692     74.68        74           0
# 2          Ushuaia -54.8000  -68.3000     37.06        87          75
# 3  Bambous Virieux -20.3428   57.7575     68.22        82          75
# 4             Tura  25.5198   90.2201     75.83        96         100
#
#    Wind Speed Country Current Description
# 0        4.61      ZA       broken clouds
# 1       10.67      PF           clear sky
# 2        5.75      AR          light rain
# 3       16.11      MU          light rain
# 4        5.88      IN     overcast clouds

# %%
# Reorder columns
new_column_order = ['City', 'Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0     Port Elizabeth      ZA -33.9180   25.5701     60.31        97
# 1            Rikitea      PF -23.1203 -134.9692     74.68        74
# 2            Ushuaia      AR -54.8000  -68.3000     37.06        87
# 3    Bambous Virieux      MU -20.3428   57.7575     68.22        82
# 4               Tura      IN  25.5198   90.2201     75.83        96
# ..               ...     ...      ...       ...       ...       ...
# 534      Yenotayevka      RU  47.2456   47.0281     75.04        60
# 535     Charyshskoye      RU  51.3978   83.5598     58.10        79
# 536           Lethem      GY   3.3803  -59.7968     75.87        88
# 537          Newport      GB  51.5877   -2.9984     78.91        60
# 538    La Paz Centro      NI  12.3400  -86.6753     81.45        73
#
#      Cloudiness  Wind Speed Current Description
# 0            75        4.61       broken clouds
# 1             0       10.67           clear sky
# 2            75        5.75          light rain
# 3            75       16.11          light rain
# 4           100        5.88     overcast clouds
# ..          ...         ...                 ...
# 534         100       16.89     overcast clouds
# 535          68        1.61       broken clouds
# 536          80        5.26       broken clouds
# 537          44        7.34    scattered clouds
# 538         100        7.78     overcast clouds
#
# [539 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = 'WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
